# %%
import pandas as pd

# %%
newdf=pd.read_csv("survey_results_public.csv")

# %%
filt=newdf['Country'].str.contains('vakia')

# %%
newdf.loc[filt,'Country']
# Out:
# 0        Slovakia
# 135      Slovakia
# 259      Slovakia
# 1721     Slovakia
# 1928     Slovakia
#            ...
# 80860    Slovakia
# 80979    Slovakia
# 81779    Slovakia
# 82209    Slovakia
# 82442    Slovakia
# Name: Country, Length: 252, dtype: object

# %%
newdf['Trans']=newdf['Trans'].replace({'Yes':True,'No':False})
#newdf['Trans'].map({'Yes':True,'No':False})

# %%
kgf=newdf['Country']=='Slovakia'
kgf
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 83434    False
# 83435    False
# 83436    False
# 83437    False
# 83438    False
# Name: Country, Length: 83439, dtype: bool

# %%
newdf.drop(index=newdf[kgf].index)
# Out:
#        ResponseId                                         MainBranch  \
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# 5               6             I am a student who is learning to code
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 1                                     Student, full-time
# ...

# %%
newdf.sort_values(by=['Country'],ascending=True,inplace=True)

# %%
newdf.sort_index(inplace=True)

# %%
newdf['ConvertedCompYearly'].nlargest(6)
# Out:
# 66910    45241312.0
# 65399    30468516.0
# 40586    21822250.0
# 28791    20000000.0
# 12700    19200000.0
# 9608     17500000.0
# Name: ConvertedCompYearly, dtype: float64

# %%
newdf.nlargest(10,'ConvertedCompYearly')
# Out:
#        ResponseId                                         MainBranch  \
# 66910       66911                     I am a developer by profession
# 65399       65400                     I am a developer by profession
# 40586       40587                     I am a developer by profession
# 28791       28792                     I am a developer by profession
# 12700       12701                     I am a developer by profession
# 9608         9609  I am not primarily a developer, but I write co...
# 5305         5306                     I am a developer by profession
# 12903       12904                     I am a developer by profession
# 66488       66489                     I am a developer by profession
# 7205         7206                     I am a developer by profession
#
#                                               Employment  \
# 66910                                I prefer not to say
# 65399                                 Employed full-time
# ...

# %%
newdf=newdf.rename(columns={'ConvertedCompYearly':'Income'})

# %%
newdf['Sexuality'].value_counts()
# Out:
# Straight / Heterosexual                                                           61094
# Prefer not to say                                                                  4783
# Bisexual                                                                           2879
# Gay or Lesbian                                                                     1367
# Prefer to self-describe:                                                           1258
# Straight / Heterosexual;Bisexual                                                    492
# Queer                                                                               376
# Bisexual;Queer                                                                      273
# Straight / Heterosexual;Prefer to self-describe:                                    225
# Gay or Lesbian;Queer                                                                149
# Straight / Heterosexual;Queer                                                        78
# ...

# %%
country=newdf.groupby(['Country'])

# %%
country['Income'].agg(['max','mean'])
# Out:
#                                              max          mean
# Country
# Afghanistan                           30468516.0  2.794748e+06
# Albania                                 692042.0  4.499814e+04
# Algeria                                  48550.0  1.446114e+04
# Andorra                                 146981.0  8.928200e+04
# Angola                                   96000.0  2.155680e+04
# ...                                          ...           ...
# Venezuela, Bolivarian Republic of...    229596.0  2.246505e+04
# Viet Nam                                258744.0  1.995289e+04
# Yemen                                    19176.0  5.628667e+03
# Zambia                                  105000.0  1.991491e+04
# Zimbabwe                                 36000.0  1.141477e+04
#
# [181 rows x 2 columns]

# %%
country['Income'].agg(['median','mean']).loc['India']
# Out:
# median    14748.000000
# mean      42522.583464
# Name: India, dtype: float64

# %%
respondant=newdf['Country'].value_counts()

# %%
respondant
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
newdf['YearsCode'].unique()
# Out:
# array([nan, '7', '17', '3', '4', '6', '16', '12', '15', '10', '40', '9',
#        '26', '14', '39', '20', '8', '19', '5', 'Less than 1 year', '22',
#        '2', '1', '34', '21', '13', '25', '24', '30', '31', '18', '38',
#        'More than 50 years', '27', '41', '42', '35', '23', '28', '11',
#        '37', '44', '43', '36', '33', '45', '29', '50', '46', '32', '47',
#        '49', '48'], dtype=object)

# %%
newdf['YearsCode']=newdf['YearsCode'].replace('Less than 1 year',0)

# %%
newdf['YearsCode']=newdf['YearsCode'].replace('More than 50 years',51)

# %%
newdf['YearsCode']=newdf['YearsCode'].astype(float)

# %%
newdf['YearsCode'].mean()
# Out:
# 12.338200169032717
